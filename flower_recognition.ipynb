# %%
#Import libraries

# %%
import numpy as np 
import tensorflow as tf

# %%
#Data preprocessing

# %%
#training Image processing

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

training_set = train_datagen.flow_from_directory(
    'training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 4017 images belonging to 5 classes.

# %%
#Test Image processing

# %%
test_datagen = ImageDataGenerator(rescale=1./255)

test_set = test_datagen.flow_from_directory(
    'test_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 4617 images belonging to 5 classes.

# %%
#building model

# %%
cnn = tf.keras.models.Sequential()

# %%
#building convolution layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.5))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
cnn.add(tf.keras.layers.Dense(units=5, activation='softmax'))

# %%
cnn.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
cnn.fit(x=training_set,validation_data=test_set, epochs=30)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python313\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - accuracy: 0.4454 - loss: 1.3210 - val_accuracy: 0.5943 - val_loss: 1.0551
# Epoch 2/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 155ms/step - accuracy: 0.5629 - loss: 1.0851 - val_accuracy: 0.5497 - val_loss: 1.1274
# Epoch 3/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.6179 - loss: 0.9919 - val_accuracy: 0.6816 - val_loss: 0.8372
# Epoch 4/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 162ms/step - accuracy: 0.6380 - loss: 0.9236 - val_accuracy: 0.5469 - val_loss: 1.1834
# Epoch 5/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 160ms/step - accuracy: 0.6654 - loss: 0.8677 - val_accuracy: 0.7011 - val_loss: 0.7617
# Epoch 6/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 160ms/step - accuracy: 0.6769 - loss: 0.8270 - val_accuracy: 0.7102 - val_loss: 0.7547
# Epoch 7/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 162ms/step - accuracy: 0.6993 - loss: 0.7812 - val_accuracy: 0.7080 - val_loss: 0.7418
# Epoch 8/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.7172 - loss: 0.7439 - val_accuracy: 0.7358 - val_loss: 0.7195
# Epoch 9/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 189s 2s/step - accuracy: 0.7428 - loss: 0.7076 - val_accuracy: 0.7695 - val_loss: 0.6135
# Epoch 10/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 63s 498ms/step - accuracy: 0.7481 - loss: 0.6704 - val_accuracy: 0.7173 - val_loss: 0.7268
# Epoch 11/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 42s 337ms/step - accuracy: 0.7456 - loss: 0.6717 - val_accuracy: 0.7940 - val_loss: 0.5803
# Epoch 12/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 43s 341ms/step - accuracy: 0.7628 - loss: 0.6335 - val_accuracy: 0.7910 - val_loss: 0.5778
# Epoch 13/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 45s 358ms/step - accuracy: 0.7692 - loss: 0.6055 - val_accuracy: 0.8018 - val_loss: 0.5548
# Epoch 14/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 42s 337ms/step - accuracy: 0.7700 - loss: 0.6002 - val_accuracy: 0.8103 - val_loss: 0.5114
# Epoch 15/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 43s 338ms/step - accuracy: 0.7879 - loss: 0.5689 - val_accuracy: 0.8417 - val_loss: 0.4552
# Epoch 16/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 42s 335ms/step - accuracy: 0.7929 - loss: 0.5504 - val_accuracy: 0.7947 - val_loss: 0.5493
# Epoch 17/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 42s 335ms/step - accuracy: 0.7936 - loss: 0.5445 - val_accuracy: 0.8527 - val_loss: 0.4220
# Epoch 18/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 29s 227ms/step - accuracy: 0.8125 - loss: 0.5175 - val_accuracy: 0.8612 - val_loss: 0.4059
# Epoch 19/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - accuracy: 0.8175 - loss: 0.4910 - val_accuracy: 0.8592 - val_loss: 0.4264
# Epoch 20/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - accuracy: 0.8160 - loss: 0.4861 - val_accuracy: 0.8618 - val_loss: 0.3913
# Epoch 21/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.8307 - loss: 0.4627 - val_accuracy: 0.8830 - val_loss: 0.3549
# Epoch 22/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 159ms/step - accuracy: 0.8359 - loss: 0.4278 - val_accuracy: 0.8911 - val_loss: 0.3354
# Epoch 23/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - accuracy: 0.8444 - loss: 0.4322 - val_accuracy: 0.8577 - val_loss: 0.4101
# Epoch 24/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - accuracy: 0.8402 - loss: 0.4197 - val_accuracy: 0.8971 - val_loss: 0.3183
# Epoch 25/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.8524 - loss: 0.4037 - val_accuracy: 0.9023 - val_loss: 0.3114
# Epoch 26/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.8554 - loss: 0.3913 - val_accuracy: 0.8616 - val_loss: 0.4158
# Epoch 27/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 20s 162ms/step - accuracy: 0.8606 - loss: 0.3876 - val_accuracy: 0.8869 - val_loss: 0.3555
# Epoch 28/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.8648 - loss: 0.3695 - val_accuracy: 0.9041 - val_loss: 0.3064
# Epoch 29/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.8681 - loss: 0.3625 - val_accuracy: 0.9244 - val_loss: 0.2598
# Epoch 30/30
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 21s 164ms/step - accuracy: 0.8780 - loss: 0.3414 - val_accuracy: 0.9179 - val_loss: 0.2718

# %%
#preprocess New Image

# %%
from keras.preprocessing import image
test_image = image.load_img('Prediction/f.jpg',target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image,axis=0)
result = cnn.predict(test_image)
training_set.class_indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
print(result)
# Out:
# [[0. 0. 0. 1. 0.]]

# %%
if result[0][0]==1:
    print('Daisy')
elif result[0][1]==1:
    print('Dandelion')
elif result[0][2]==1:
    print('Rose')
elif result[0][3]==1:
    print('SunFlower')
elif result[0][4]==1:
    print("Tulip")
# Out:
# SunFlower
